# %% [markdown]
# # Healthy Aging

# %% [markdown]
# The topic of aging and death is one that pervades conversations and societies alike. Our relationship with death is one of both acceptance and prolonging.
#
# The Department of Health and Human Services have provided the public with a dataset of information collected on human activity and health from 2015 to 2021. I will be analyzing this data to see if I can find any interesting patterns or answer any questions.

# %%
from matplotlib import pyplot as plt
from scipy.stats import chi2_contingency

import pandas as pd
import numpy as np
import seaborn as sns
import itertools

# %%
aging_data = pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv', encoding='utf-8', low_memory=False)

# %%
aging_data.head()
# Out:
#                                       RowId  YearStart  YearEnd LocationAbbr  \
# 0   BRFSS~2015~2015~9002~Q43~TOC11~AGE~RACE       2015     2015          MDW
# 1   BRFSS~2015~2015~66~Q43~TOC11~AGE~GENDER       2015     2015           GU
# 2   BRFSS~2015~2015~9002~Q43~TOC11~AGE~RACE       2015     2015          MDW
# 3   BRFSS~2015~2015~16~Q27~TMC03~AGE~GENDER       2015     2015           ID
# 4  BRFSS~2015~2015~18~Q43~TOC11~AGE~OVERALL       2015     2015           IN
#
#   LocationDesc Datasource           Class                             Topic  \
# 0      Midwest      BRFSS  Overall Health      Arthritis among older adults
# 1         Guam      BRFSS  Overall Health      Arthritis among older adults
# 2      Midwest      BRFSS  Overall Health      Arthritis among older adults
# 3        Idaho      BRFSS   Mental Health  Lifetime diagnosis of depression
# 4      Indiana      BRFSS  Overall Health      Arthritis among older adults
#
#                                             Question  Response  ...  \
# 0  Percentage of older adults ever told they have...       NaN  ...
# 1  Percentage of older adults ever told they have...       NaN  ...
# 2  Percentage of older adults ever told they have...       NaN  ...
# 3  Percentage of older adults with a lifetime dia...       NaN  ...
# 4  Percentage of older adults ever told they have...       NaN  ...
#
#   QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 0        Q43        NaN       9002                        AGE
# 1        Q43        NaN         66                        AGE
# 2        Q43        NaN       9002                        AGE
# 3        Q27        NaN         16                        AGE
# 4        Q43        NaN         18                        AGE
#
#    StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0             65PLUS                      RACE               NAA
# 1               5064                    GENDER            FEMALE
# 2        AGE_OVERALL                      RACE               BLK
# 3               5064                    GENDER              MALE
# 4        AGE_OVERALL                   OVERALL           OVERALL
#
#   StratificationCategoryID3 StratificationID3  Report
# 0                       NaN               NaN     NaN
# 1                       NaN               NaN     NaN
# 2                       NaN               NaN     NaN
# 3                       NaN               NaN     NaN
# 4                       NaN               NaN     NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# This is a relatively daunting dataset, but we can work with it pretty well. The important columns to note are the following:
#
# 1) YearStart, YearEnd - These columns indicate the year in which that row of data was collected.
# 2) Class, Topic, Question - These three columns provide more specificity for what a given row of data is measuring.
# 3) DataValue columns - These columns provide numeric answers (and units) to the questions asked using the above columns.
# 4) ConfidenceLimit columns - These columns tell us the upper and lower bounds that HHS has set on the "true" answers to the questions asked*. This may be confusing to some readers - I will explain the statistics behind this below.
# 5) Stratification columns - These columns give demographical specifications for who is being sampled with the question in the row.
#
# **Statistical Explanation for 4)**
# In statistics, we often describe upper and lower bounds for the "actual" numeric answer to a question when we're dealing with a sample of answers. This is good for studying the US population because it is difficult to ask every single person we are trying to study within such a large population. As such, we describe the bounds, which come together to form what is known as a Confidence Interval.
#
# Confidence Intervals often come with percentage specifications, which tell us how *confident* we are that the actual answer falls in that *interval*. When the percentage is not given, such as in this data set, it is custom to assume a value of 95%. Thus, we will treat the confidence intervals provided as 95% confidence intervals (CIs). This means that we say with 95% confidence that the true answer falls in the given interval.
#
# The true answer, of course, being the answer for the entire population being studied, as opposed to the data collected, which applies to the sample that was studied.

# %% [markdown]
# ## Separating Data

# %% [markdown]
# As someone who cares significantly about mental health, my first investigation will be into questions of depressing. Furthermore, I'm interested in difference across regions, as that's something that this dataset allows us to measure.

# %%
aging_northeast = aging_data[aging_data["LocationAbbr"] == "NRE"]
aging_midwest = aging_data[aging_data["LocationAbbr"] == "MDW"]
aging_south = aging_data[aging_data["LocationAbbr"] == "SOU"]
aging_west = aging_data[aging_data["LocationAbbr"] == "WEST"]

# %% [markdown]
# We now have four tables, each separated by region of data collected. The data set also allows you to search a specific state, but I thought that would be a bit too small scale, not to mention unwieldy. Plus, I have a separate personal interest in the Northeast, as someone who's spent my life in various parts of that region.

# %%
aging_northeast.head(10)
# Out:
#                                            RowId  YearStart  YearEnd  \
# 19       BRFSS~2015~2015~9001~Q03~TMC01~AGE~RACE       2015     2015
# 24     BRFSS~2015~2015~9001~Q08~TOC01~AGE~GENDER       2015     2015
# 31       BRFSS~2015~2015~9001~Q03~TMC01~AGE~RACE       2015     2015
# 37       BRFSS~2015~2015~9001~Q43~TOC11~AGE~RACE       2015     2015
# 39       BRFSS~2015~2015~9001~Q35~TOC03~AGE~RACE       2015     2015
# 4099     BRFSS~2015~2015~9001~Q35~TOC03~AGE~RACE       2015     2015
# 12698    BRFSS~2015~2015~9001~Q43~TOC11~AGE~RACE       2015     2015
# 18663    BRFSS~2015~2015~9001~Q30~TCC01~AGE~RACE       2015     2015
# 18686    BRFSS~2015~2015~9001~Q33~TOC08~AGE~RACE       2015     2015
# 18719    BRFSS~2015~2015~9001~Q45~TOC13~AGE~RACE       2015     2015
#
#       LocationAbbr LocationDesc Datasource              Class  \
# 19             NRE    Northeast      BRFSS      Mental Health
# 24             NRE    Northeast      BRFSS     Overall Health
# 31             NRE    Northeast      BRFSS      Mental Health
# 37             NRE    Northeast      BRFSS     Overall Health
# 39             NRE    Northeast      BRFSS     Overall Health
# 4099           NRE    Northeast      BRFSS     Overall Health
# 12698          NRE    Northeast      BRFSS     Overall Health
# 18663          NRE    Northeast      BRFSS  Cognitive Decline
# 18686          NRE    Northeast      BRFSS     Overall Health
# 18719          NRE    Northeast      BRFSS     Overall Health
#
#                                                    Topic  \
# 19                              Frequent mental distress
# 24       Physically unhealthy days (mean number of days)
# 31                              Frequent mental distress
# 37                          Arthritis among older adults
# 39             Recent activity limitations in past month
# 4099           Recent activity limitations in past month
# 12698                       Arthritis among older adults
# 18663  Subjective cognitive decline or memory loss am...
# 18686       Self-rated health (good to excellent health)
# 18719  Fair or poor health among older adults with ar...
#
#                                                 Question  Response  ...  \
# 19     Percentage of older adults who are experiencin...       NaN  ...
# 24     Physically unhealthy days (mean number of days...       NaN  ...
# 31     Percentage of older adults who are experiencin...       NaN  ...
# 37     Percentage of older adults ever told they have...       NaN  ...
# 39     Mean number of days with activity limitations ...       NaN  ...
# 4099   Mean number of days with activity limitations ...       NaN  ...
# 12698  Percentage of older adults ever told they have...       NaN  ...
# 18663  Percentage of older adults who reported subjec...       NaN  ...
# 18686  Percentage of older adults who self-reported t...       NaN  ...
# 18719  Fair or poor health among older adults with do...       NaN  ...
#
#       QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 19           Q03        NaN       9001                        AGE
# 24           Q08        NaN       9001                        AGE
# 31           Q03        NaN       9001                        AGE
# 37           Q43        NaN       9001                        AGE
# 39           Q35        NaN       9001                        AGE
# 4099         Q35        NaN       9001                        AGE
# 12698        Q43        NaN       9001                        AGE
# 18663        Q30        NaN       9001                        AGE
# 18686        Q33        NaN       9001                        AGE
# 18719        Q45        NaN       9001                        AGE
#
#        StratificationID1 StratificationCategoryID2 StratificationID2  \
# 19                  5064                      RACE               BLK
# 24                65PLUS                    GENDER              MALE
# 31                  5064                      RACE               WHT
# 37           AGE_OVERALL                      RACE               ASN
# 39           AGE_OVERALL                      RACE               HIS
# 4099                5064                      RACE               WHT
# 12698        AGE_OVERALL                      RACE               NAA
# 18663               5064                      RACE               ASN
# 18686             65PLUS                      RACE               ASN
# 18719               5064                      RACE               BLK
#
#       StratificationCategoryID3 StratificationID3  Report
# 19                          NaN               NaN     NaN
# 24                          NaN               NaN     NaN
# 31                          NaN               NaN     NaN
# 37                          NaN               NaN     NaN
# 39                          NaN               NaN     NaN
# 4099                        NaN               NaN     NaN
# 12698                       NaN               NaN     NaN
# 18663                       NaN               NaN     NaN
# 18686                       NaN               NaN     NaN
# 18719                       NaN               NaN     NaN
#
# [10 rows x 39 columns]

# %% [markdown]
# Interesting Note: Since this is a study on aging, we have only two age-based stratifications: 50-64 years old, and 65+.

# %% [markdown]
# ## Sample Question

# %% [markdown]
# Just to establish how we're going to go about answer any given question, we're going to start with something very easy, simply measuring lifetime depression diagnosis over time for certain groups.

# %%
aging_nre_depression = aging_northeast[aging_northeast["QuestionID"] == "Q27"]
aging_mdw_depression = aging_midwest[aging_midwest["QuestionID"] == "Q27"]
aging_south_depression = aging_south[aging_south["QuestionID"] == "Q27"]
aging_west_depression = aging_west[aging_west["QuestionID"] == "Q27"]
# Q27: Percentage of older adults with a lifetime diagnosis of depression

# %%
aging_nre_depression # Getting a view of one of the above tables
# Out:
#                                             RowId  YearStart  YearEnd  \
# 19936     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# 20357     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# 20473   BRFSS~2015~2015~9001~Q27~TMC03~AGE~GENDER       2015     2015
# 20604   BRFSS~2015~2015~9001~Q27~TMC03~AGE~GENDER       2015     2015
# 21788     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# ...                                           ...        ...      ...
# 236422    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 239758    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 240171  BRFSS~2021~2021~9001~Q27~TMC03~AGE~GENDER       2021     2021
# 247728    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 249997  BRFSS~2021~2021~9001~Q27~TMC03~AGE~GENDER       2021     2021
#
#        LocationAbbr LocationDesc Datasource          Class  \
# 19936           NRE    Northeast      BRFSS  Mental Health
# 20357           NRE    Northeast      BRFSS  Mental Health
# 20473           NRE    Northeast      BRFSS  Mental Health
# 20604           NRE    Northeast      BRFSS  Mental Health
# 21788           NRE    Northeast      BRFSS  Mental Health
# ...             ...          ...        ...            ...
# 236422          NRE    Northeast      BRFSS  Mental Health
# 239758          NRE    Northeast      BRFSS  Mental Health
# 240171          NRE    Northeast      BRFSS  Mental Health
# 247728          NRE    Northeast      BRFSS  Mental Health
# 249997          NRE    Northeast      BRFSS  Mental Health
#
#                                    Topic  \
# 19936   Lifetime diagnosis of depression
# 20357   Lifetime diagnosis of depression
# 20473   Lifetime diagnosis of depression
# 20604   Lifetime diagnosis of depression
# 21788   Lifetime diagnosis of depression
# ...                                  ...
# 236422  Lifetime diagnosis of depression
# 239758  Lifetime diagnosis of depression
# 240171  Lifetime diagnosis of depression
# 247728  Lifetime diagnosis of depression
# 249997  Lifetime diagnosis of depression
#
#                                                  Question  Response  ...  \
# 19936   Percentage of older adults with a lifetime dia...       NaN  ...
# 20357   Percentage of older adults with a lifetime dia...       NaN  ...
# 20473   Percentage of older adults with a lifetime dia...       NaN  ...
# 20604   Percentage of older adults with a lifetime dia...       NaN  ...
# 21788   Percentage of older adults with a lifetime dia...       NaN  ...
# ...                                                   ...       ...  ...
# 236422  Percentage of older adults with a lifetime dia...       NaN  ...
# 239758  Percentage of older adults with a lifetime dia...       NaN  ...
# 240171  Percentage of older adults with a lifetime dia...       NaN  ...
# 247728  Percentage of older adults with a lifetime dia...       NaN  ...
# 249997  Percentage of older adults with a lifetime dia...       NaN  ...
#
#        QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 19936         Q27        NaN       9001                        AGE
# 20357         Q27        NaN       9001                        AGE
# 20473         Q27        NaN       9001                        AGE
# 20604         Q27        NaN       9001                        AGE
# 21788         Q27        NaN       9001                        AGE
# ...           ...        ...        ...                        ...
# 236422        Q27        NaN       9001                        AGE
# 239758        Q27        NaN       9001                        AGE
# 240171        Q27        NaN       9001                        AGE
# 247728        Q27        NaN       9001                        AGE
# 249997        Q27        NaN       9001                        AGE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 19936              65PLUS                      RACE               WHT
# 20357                5064                      RACE               ASN
# 20473              65PLUS                    GENDER            FEMALE
# 20604                5064                    GENDER              MALE
# 21788              65PLUS                      RACE               BLK
# ...                   ...                       ...               ...
# 236422        AGE_OVERALL                      RACE               WHT
# 239758             65PLUS                      RACE               BLK
# 240171        AGE_OVERALL                    GENDER              MALE
# 247728               5064                      RACE               HIS
# 249997               5064                    GENDER              MALE
#
#        StratificationCategoryID3 StratificationID3  Report
# 19936                        NaN               NaN     NaN
# 20357                        NaN               NaN     NaN
# 20473                        NaN               NaN     NaN
# 20604                        NaN               NaN     NaN
# 21788                        NaN               NaN     NaN
# ...                          ...               ...     ...
# 236422                       NaN               NaN     NaN
# 239758                       NaN               NaN     NaN
# 240171                       NaN               NaN     NaN
# 247728                       NaN               NaN     NaN
# 249997                       NaN               NaN     NaN
#
# [168 rows x 39 columns]

# %%
aging_nre_depression.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_nre_depression.csv') # This line of code
                                                                    # creates a CSV file on my computer of the table
                                                                    # above. This allows me to look at it in greater
                                                                    # detail outside of Jupyter.

# %% [markdown]
# Upon inspection, some rows in this dataframe will be unusable in any analysis because of a small sample size. As such, we'll want to get rid of them before performing any further action.

# %%
aging_nre_depression_final = aging_nre_depression[aging_nre_depression['Data_Value'].notna()] # Drops rows with blank cells
                                                                                              # in the Data_Value column

# %%
aging_nre_depression_final
# Out:
#                                             RowId  YearStart  YearEnd  \
# 19936     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# 20473   BRFSS~2015~2015~9001~Q27~TMC03~AGE~GENDER       2015     2015
# 20604   BRFSS~2015~2015~9001~Q27~TMC03~AGE~GENDER       2015     2015
# 21788     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# 24528     BRFSS~2015~2015~9001~Q27~TMC03~AGE~RACE       2015     2015
# ...                                           ...        ...      ...
# 236422    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 239758    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 240171  BRFSS~2021~2021~9001~Q27~TMC03~AGE~GENDER       2021     2021
# 247728    BRFSS~2021~2021~9001~Q27~TMC03~AGE~RACE       2021     2021
# 249997  BRFSS~2021~2021~9001~Q27~TMC03~AGE~GENDER       2021     2021
#
#        LocationAbbr LocationDesc Datasource          Class  \
# 19936           NRE    Northeast      BRFSS  Mental Health
# 20473           NRE    Northeast      BRFSS  Mental Health
# 20604           NRE    Northeast      BRFSS  Mental Health
# 21788           NRE    Northeast      BRFSS  Mental Health
# 24528           NRE    Northeast      BRFSS  Mental Health
# ...             ...          ...        ...            ...
# 236422          NRE    Northeast      BRFSS  Mental Health
# 239758          NRE    Northeast      BRFSS  Mental Health
# 240171          NRE    Northeast      BRFSS  Mental Health
# 247728          NRE    Northeast      BRFSS  Mental Health
# 249997          NRE    Northeast      BRFSS  Mental Health
#
#                                    Topic  \
# 19936   Lifetime diagnosis of depression
# 20473   Lifetime diagnosis of depression
# 20604   Lifetime diagnosis of depression
# 21788   Lifetime diagnosis of depression
# 24528   Lifetime diagnosis of depression
# ...                                  ...
# 236422  Lifetime diagnosis of depression
# 239758  Lifetime diagnosis of depression
# 240171  Lifetime diagnosis of depression
# 247728  Lifetime diagnosis of depression
# 249997  Lifetime diagnosis of depression
#
#                                                  Question  Response  ...  \
# 19936   Percentage of older adults with a lifetime dia...       NaN  ...
# 20473   Percentage of older adults with a lifetime dia...       NaN  ...
# 20604   Percentage of older adults with a lifetime dia...       NaN  ...
# 21788   Percentage of older adults with a lifetime dia...       NaN  ...
# 24528   Percentage of older adults with a lifetime dia...       NaN  ...
# ...                                                   ...       ...  ...
# 236422  Percentage of older adults with a lifetime dia...       NaN  ...
# 239758  Percentage of older adults with a lifetime dia...       NaN  ...
# 240171  Percentage of older adults with a lifetime dia...       NaN  ...
# 247728  Percentage of older adults with a lifetime dia...       NaN  ...
# 249997  Percentage of older adults with a lifetime dia...       NaN  ...
#
#        QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 19936         Q27        NaN       9001                        AGE
# 20473         Q27        NaN       9001                        AGE
# 20604         Q27        NaN       9001                        AGE
# 21788         Q27        NaN       9001                        AGE
# 24528         Q27        NaN       9001                        AGE
# ...           ...        ...        ...                        ...
# 236422        Q27        NaN       9001                        AGE
# 239758        Q27        NaN       9001                        AGE
# 240171        Q27        NaN       9001                        AGE
# 247728        Q27        NaN       9001                        AGE
# 249997        Q27        NaN       9001                        AGE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 19936              65PLUS                      RACE               WHT
# 20473              65PLUS                    GENDER            FEMALE
# 20604                5064                    GENDER              MALE
# 21788              65PLUS                      RACE               BLK
# 24528         AGE_OVERALL                      RACE               NAA
# ...                   ...                       ...               ...
# 236422        AGE_OVERALL                      RACE               WHT
# 239758             65PLUS                      RACE               BLK
# 240171        AGE_OVERALL                    GENDER              MALE
# 247728               5064                      RACE               HIS
# 249997               5064                    GENDER              MALE
#
#        StratificationCategoryID3 StratificationID3  Report
# 19936                        NaN               NaN     NaN
# 20473                        NaN               NaN     NaN
# 20604                        NaN               NaN     NaN
# 21788                        NaN               NaN     NaN
# 24528                        NaN               NaN     NaN
# ...                          ...               ...     ...
# 236422                       NaN               NaN     NaN
# 239758                       NaN               NaN     NaN
# 240171                       NaN               NaN     NaN
# 247728                       NaN               NaN     NaN
# 249997                       NaN               NaN     NaN
#
# [156 rows x 39 columns]

# %%
aging_nre_depression_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_nre_depression.csv')

# %% [markdown]
# Now that we've done this to one set, we can do it with the other 3 before starting further analysis.

# %%
aging_mdw_depression_final = aging_mdw_depression[aging_mdw_depression['Data_Value'].notna()]
aging_mdw_depression_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_mdw_depression.csv')

aging_south_depression_final = aging_south_depression[aging_south_depression['Data_Value'].notna()]
aging_south_depression_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_south_depression.csv')

aging_west_depression_final = aging_west_depression[aging_west_depression['Data_Value'].notna()]
aging_west_depression_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_west_depression.csv')

# %% [markdown]
# With that done, I now have access to all four depression tables, with the small samples removed. This will allow us to perform some good further analysis.
#
# The date are all stratified by age, and further between race and gender. This means that every row has an age group attached to it, but only one race OR gender.
#
# For simplicity, I'm going to start with gender - mental health has become a more gender-centric topic over the years, so I'm interested to see what results come from this above others. However, we have to pick an age group to sample from - because my focus is on gender, I will be using the "overall" section when it comes to age, rather than picking one group or the other.

# %%
aging_nre_depression_final = aging_nre_depression_final[aging_nre_depression_final["StratificationID1"] == "AGE_OVERALL"]

# %%
aging_nre_depression_final_male = aging_nre_depression_final[aging_nre_depression_final['StratificationID2'] == "MALE"]
aging_nre_depression_final_female = aging_nre_depression_final[aging_nre_depression_final['StratificationID2'] == "FEMALE"]

# %%
aging_nre_depression_final_male
# Out:
#                                             RowId  YearStart  YearEnd  \
# 25028   BRFSS~2015~2015~9001~Q27~TMC03~AGE~GENDER       2015     2015
# 55313   BRFSS~2016~2016~9001~Q27~TMC03~AGE~GENDER       2016     2016
# 95784   BRFSS~2017~2017~9001~Q27~TMC03~AGE~GENDER       2017     2017
# 127137  BRFSS~2018~2018~9001~Q27~TMC03~AGE~GENDER       2018     2018
# 165625  BRFSS~2019~2019~9001~Q27~TMC03~AGE~GENDER       2019     2019
# 173430  BRFSS~2020~2020~9001~Q27~TMC03~AGE~GENDER       2020     2020
# 240171  BRFSS~2021~2021~9001~Q27~TMC03~AGE~GENDER       2021     2021
#
#        LocationAbbr LocationDesc Datasource          Class  \
# 25028           NRE    Northeast      BRFSS  Mental Health
# 55313           NRE    Northeast      BRFSS  Mental Health
# 95784           NRE    Northeast      BRFSS  Mental Health
# 127137          NRE    Northeast      BRFSS  Mental Health
# 165625          NRE    Northeast      BRFSS  Mental Health
# 173430          NRE    Northeast      BRFSS  Mental Health
# 240171          NRE    Northeast      BRFSS  Mental Health
#
#                                    Topic  \
# 25028   Lifetime diagnosis of depression
# 55313   Lifetime diagnosis of depression
# 95784   Lifetime diagnosis of depression
# 127137  Lifetime diagnosis of depression
# 165625  Lifetime diagnosis of depression
# 173430  Lifetime diagnosis of depression
# 240171  Lifetime diagnosis of depression
#
#                                                  Question  Response  ...  \
# 25028   Percentage of older adults with a lifetime dia...       NaN  ...
# 55313   Percentage of older adults with a lifetime dia...       NaN  ...
# 95784   Percentage of older adults with a lifetime dia...       NaN  ...
# 127137  Percentage of older adults with a lifetime dia...       NaN  ...
# 165625  Percentage of older adults with a lifetime dia...       NaN  ...
# 173430  Percentage of older adults with a lifetime dia...       NaN  ...
# 240171  Percentage of older adults with a lifetime dia...       NaN  ...
#
#        QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 25028         Q27        NaN       9001                        AGE
# 55313         Q27        NaN       9001                        AGE
# 95784         Q27        NaN       9001                        AGE
# 127137        Q27        NaN       9001                        AGE
# 165625        Q27        NaN       9001                        AGE
# 173430        Q27        NaN       9001                        AGE
# 240171        Q27        NaN       9001                        AGE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 25028         AGE_OVERALL                    GENDER              MALE
# 55313         AGE_OVERALL                    GENDER              MALE
# 95784         AGE_OVERALL                    GENDER              MALE
# 127137        AGE_OVERALL                    GENDER              MALE
# 165625        AGE_OVERALL                    GENDER              MALE
# 173430        AGE_OVERALL                    GENDER              MALE
# 240171        AGE_OVERALL                    GENDER              MALE
#
#        StratificationCategoryID3 StratificationID3  Report
# 25028                        NaN               NaN     NaN
# 55313                        NaN               NaN     NaN
# 95784                        NaN               NaN     NaN
# 127137                       NaN               NaN     NaN
# 165625                       NaN               NaN     NaN
# 173430                       NaN               NaN     NaN
# 240171                       NaN               NaN     NaN
#
# [7 rows x 39 columns]

# %% [markdown]
# We've finally figured out a series of steps to curate our data down to something we can graph. Now we can form it into a list.

# %%
male_depression_all_ages = []
for index, row in aging_nre_depression_final_male.iterrows():
    male_depression_all_ages.append(row["Data_Value"])

# %%
female_depression_all_ages = []
for index, row in aging_nre_depression_final_female.iterrows():
    female_depression_all_ages.append(row["Data_Value"])

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(years, male_depression_all_ages)
plt.plot(years, female_depression_all_ages)
plt.ylim(0, 40)
plt.title("Lifetime Depression Diagnosis (%), Northeast US Adults 50 and Older")
plt.xlabel("Year")
plt.ylabel("Lifetime Depression Diagnosis %")
plt.legend(["Men", "Women"])

# %% [markdown]
# As we can see, male depression diagnosis is maintained between 10 and 15 percent, whereas women are hovering around 20%.

# %% [markdown]
# ## Deeper Analysis

# %% [markdown]
# Now that we've gotten an idea of how we want to chop up our data for analysis, we can ask and answer more complex questions. The first curiosity that comes to mind for me is a potential comparison between depression and unhealthy weight.
#
# Since we already have databases curated for depression, we will now make some for obesity.

# %%
aging_nre_obesity = aging_northeast[aging_northeast["QuestionID"] == "Q13"] 
aging_mdw_obesity = aging_midwest[aging_midwest["QuestionID"] == "Q13"]
aging_south_obesity = aging_south[aging_south["QuestionID"] == "Q13"]
aging_west_obesity = aging_west[aging_west["QuestionID"] == "Q13"]
# Q13: Percentage of older adults who are currently obese, with a body mass index (BMI) of 30 or more

# %% [markdown]
# I also want to compare region to region for this question now that we've left example territory.

# %%
aging_nre_obesity_final = aging_nre_obesity[aging_nre_obesity['Data_Value'].notna()]
aging_nre_obesity_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_nre_obesity.csv')

aging_mdw_obesity_final = aging_mdw_obesity[aging_mdw_obesity['Data_Value'].notna()]
aging_mdw_obesity_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_mdw_obesity.csv')

aging_south_obesity_final = aging_south_obesity[aging_south_obesity['Data_Value'].notna()]
aging_south_obesity_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_south_obesity.csv')

aging_west_obesity_final = aging_west_obesity[aging_west_obesity['Data_Value'].notna()]
aging_west_obesity_final.to_csv(r'C:\Important Things\Job Stuff\Projects\aging_west_obesity.csv')

# %% [markdown]
# I'm still not particularly interested in separating by age group, so I will be filtering down to all ages for each of these.

# %%
aging_mdw_depression_final = aging_mdw_depression_final[aging_mdw_depression_final["StratificationID1"] == "AGE_OVERALL"]
aging_south_depression_final = aging_south_depression_final[aging_south_depression_final["StratificationID1"] == "AGE_OVERALL"]
aging_west_depression_final = aging_west_depression_final[aging_west_depression_final["StratificationID1"] == "AGE_OVERALL"]

aging_nre_obesity_final = aging_nre_obesity_final[aging_nre_obesity_final["StratificationID1"] == "AGE_OVERALL"]
aging_mdw_obesity_final = aging_mdw_obesity_final[aging_mdw_obesity_final["StratificationID1"] == "AGE_OVERALL"]
aging_south_obesity_final = aging_south_obesity_final[aging_south_obesity_final["StratificationID1"] == "AGE_OVERALL"]
aging_west_obesity_final = aging_west_obesity_final[aging_west_obesity_final["StratificationID1"] == "AGE_OVERALL"]

# %% [markdown]
# We now have eight tables, four for depression and four for obesity - all using solely "all ages" for our age group.
#
# We now have to decide what to do about our second stratification; we could use race or gender. For now we will stick to gender, as we have a gender stratification in place from our example. Starting with gender only will allow us to build on our previous results - having the previous tables allows us to quickly create templates for our other tables.

# %%
# aging_nre_depression_final_male
# aging_nre_depression_final_female

aging_nre_obesity_final_male = aging_nre_obesity_final[aging_nre_obesity_final['StratificationID2'] == "MALE"]
aging_nre_obesity_final_female = aging_nre_obesity_final[aging_nre_obesity_final['StratificationID2'] == "FEMALE"]

aging_mdw_depression_final_male = aging_mdw_depression_final[aging_mdw_depression_final['StratificationID2'] == "MALE"]
aging_mdw_depression_final_female = aging_mdw_depression_final[aging_mdw_depression_final['StratificationID2'] == "FEMALE"] 

aging_mdw_obesity_final_male = aging_mdw_obesity_final[aging_mdw_obesity_final['StratificationID2'] == "MALE"]
aging_mdw_obesity_final_female = aging_mdw_obesity_final[aging_mdw_obesity_final['StratificationID2'] == "FEMALE"]

aging_south_depression_final_male = aging_south_depression_final[aging_south_depression_final['StratificationID2'] == "MALE"]
aging_south_depression_final_female = aging_south_depression_final[aging_south_depression_final['StratificationID2'] == "FEMALE"] 

aging_south_obesity_final_male = aging_south_obesity_final[aging_south_obesity_final['StratificationID2'] == "MALE"]
aging_south_obesity_final_female = aging_south_obesity_final[aging_south_obesity_final['StratificationID2'] == "FEMALE"]

aging_west_depression_final_male = aging_west_depression_final[aging_west_depression_final['StratificationID2'] == "MALE"]
aging_west_depression_final_female = aging_west_depression_final[aging_west_depression_final['StratificationID2'] == "FEMALE"] 

aging_west_obesity_final_male = aging_west_obesity_final[aging_west_obesity_final['StratificationID2'] == "MALE"]
aging_west_obesity_final_female = aging_west_obesity_final[aging_west_obesity_final['StratificationID2'] == "FEMALE"]

# %% [markdown]
# ### Depression/Obesity - Lists and Graphs

# %% [markdown]
# With our tables set, it's time to turn them into lists. We can do this the same way we did it the first time, just repeating many times.

# %%
male_nre_depression_all_ages = male_depression_all_ages # Renaming our NRE depression lists for consistency
female_nre_depression_all_ages = female_depression_all_ages # with the ones we're about to make

# %%
male_nre_obesity_all_ages = []
for index, row in aging_nre_obesity_final_male.iterrows():
    male_nre_obesity_all_ages.append(row["Data_Value"])

female_nre_obesity_all_ages = []
for index, row in aging_nre_obesity_final_female.iterrows():
    female_nre_obesity_all_ages.append(row["Data_Value"])

# MIDWEST

male_mdw_depression_all_ages = []
for index, row in aging_mdw_depression_final_male.iterrows():
    male_mdw_depression_all_ages.append(row["Data_Value"])
    
female_mdw_depression_all_ages = []
for index, row in aging_mdw_depression_final_female.iterrows():
    female_mdw_depression_all_ages.append(row["Data_Value"])
    
male_mdw_obesity_all_ages = []
for index, row in aging_mdw_obesity_final_male.iterrows():
    male_mdw_obesity_all_ages.append(row["Data_Value"])

female_mdw_obesity_all_ages = []
for index, row in aging_mdw_obesity_final_female.iterrows():
    female_mdw_obesity_all_ages.append(row["Data_Value"])
    
# SOUTH

male_south_depression_all_ages = []
for index, row in aging_south_depression_final_male.iterrows():
    male_south_depression_all_ages.append(row["Data_Value"])
    
female_south_depression_all_ages = []
for index, row in aging_south_depression_final_female.iterrows():
    female_south_depression_all_ages.append(row["Data_Value"])
    
male_south_obesity_all_ages = []
for index, row in aging_south_obesity_final_male.iterrows():
    male_south_obesity_all_ages.append(row["Data_Value"])

female_south_obesity_all_ages = []
for index, row in aging_south_obesity_final_female.iterrows():
    female_south_obesity_all_ages.append(row["Data_Value"])
    
# WEST
    
male_west_depression_all_ages = []
for index, row in aging_west_depression_final_male.iterrows():
    male_west_depression_all_ages.append(row["Data_Value"])
    
female_west_depression_all_ages = []
for index, row in aging_west_depression_final_female.iterrows():
    female_west_depression_all_ages.append(row["Data_Value"])
    
male_west_obesity_all_ages = []
for index, row in aging_west_obesity_final_male.iterrows():
    male_west_obesity_all_ages.append(row["Data_Value"])

female_west_obesity_all_ages = []
for index, row in aging_west_obesity_final_female.iterrows():
    female_west_obesity_all_ages.append(row["Data_Value"])

# %% [markdown]
# ### First - Who's the Most Afflicted?

# %% [markdown]
# Before I jump into comparing depression and obesity, I'm interested in finding which region of the US has the highest rates of depression diagnosis and/or unhealthy BMI. So I will be creating charts for those first.

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(years, male_nre_depression_all_ages)
plt.plot(years, male_mdw_depression_all_ages)
plt.plot(years, male_south_depression_all_ages)
plt.plot(years, male_west_depression_all_ages)
plt.ylim(0, 40)
plt.title("Lifetime Depression Diagnosis %, US Men Age 50 and Older")
plt.xlabel("Year")
plt.ylabel("% of 50+ year-old Men with Depression Diagnosis")
plt.legend(["Northeast", "Midwest", "South", "West"])

# %% [markdown]
# As we can see, there are slightly higher depression levels in the South, but just barely. We're talking about a difference of maybe 1 or 2 percentage points. For most intents and purposes, we can say there's little difference at all. But what about obesity levels?

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(years, male_nre_obesity_all_ages)
plt.plot(years, male_mdw_obesity_all_ages)
plt.plot(years, male_south_obesity_all_ages)
plt.plot(years, male_west_obesity_all_ages)
plt.ylim(0, 40)
plt.title("BMI Over 30 (%), US Men Age 50 and Older")
plt.xlabel("Year")
plt.ylabel("% of 50+ year-old Men with a BMI over 30")
plt.legend(["Northeast", "Midwest", "South", "West"])

# %% [markdown]
# Now this, is a much higher disparity. Men from the Midwest and South are the highest, creeping closer to 40 (!) percent as the years tick by. In contrast, men from the West are the only group under 30 percent, with Northeast nestled in the middle of those two extremes.
#
# A ten percentage point difference here means that southern and midwestern men are more than one third more likely to suffer from obesity than western men. This indicates that there may be something about the lifestyles of these different groups that could be causing the disparity. But we will go into that later.
#
# For now, we will do the same thing we just did, only for women instead of men.

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(years, female_nre_depression_all_ages)
plt.plot(years, female_mdw_depression_all_ages)
plt.plot(years, female_south_depression_all_ages)
plt.plot(years, female_west_depression_all_ages)
plt.ylim(0, 40)
plt.title("Lifetime Depression Diagnosis %, US Women Age 50 and Older")
plt.xlabel("Year")
plt.ylabel("% of 50+ year-old Womeen with Depression Diagnosis")
plt.legend(["Northeast", "Midwest", "South", "West"])

# %% [markdown]
# As we can see, when it comes to older folks, women tend to have a significantly higher depression rare than men. None of our four regions saw a male lifetime depression diagnosis % higher than 20, whereas that threshold seems to be a minimum for women, with only Northeast women dipping below it at any point.

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(years, female_nre_obesity_all_ages)
plt.plot(years, female_mdw_obesity_all_ages)
plt.plot(years, female_south_obesity_all_ages)
plt.plot(years, female_west_obesity_all_ages)
plt.ylim(0, 40)
plt.title("BMI Over 30 (%), US Women Age 50 and Older")
plt.xlabel("Year")
plt.ylabel("% of 50+ year-old Women with a BMI over 30")
plt.legend(["Northeast", "Midwest", "South", "West"])

# %% [markdown]
# Obesity levels seem to generate a similar pattern to the one we saw in men, only this time we have South slightly edging out Midwest, whereas with men it was the other way around. Northeast and West are behaving in a similar way.

# %% [markdown]
# ## Depression vs. Obesity - Overall

# %% [markdown]
# Overall, what I can see from this comparison is a few things:
# 1) Women are more likely to have a lifetime depression diagnosis than men.
# 2) People from the South and Midwest are more likely to have an obese BMI (>30).
# 3) Obesity levels are creeping up across the board, whereas depression levels are steadier.
